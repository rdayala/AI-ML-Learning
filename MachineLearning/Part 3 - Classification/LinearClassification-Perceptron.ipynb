# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import random

# %%
plus_list = []
train_labels = []
minus_list = []
labels_plus_list = []
labels_minus_list = []
test_plus_list = []
test_labels_plus_list = []
test_minus_list = []
test_labels_minus_list = [] 

for x in range(0, 20):
    for y in range(0, 20):
        if((y > x) and random.random() > 0.7):
            plus_list.append(tuple((x,y)))
            labels_plus_list.append('+')
        if((y < x) and random.random() > 0.7):
            minus_list.append(tuple((x,y)))
            labels_minus_list.append('-')
        if((y > x) and random.random() < 0.7):
            test_plus_list.append(tuple((x,y)))
            test_labels_plus_list.append('+')
        if((y < x) and random.random() < 0.7):
            test_minus_list.append(tuple((x,y)))
            test_labels_minus_list.append('-')
            

#print(plus_list)
#print(minus_list)
train_data = plus_list + minus_list
train_labels = labels_plus_list + labels_minus_list
test_data = test_plus_list + test_minus_list
test_labels = test_labels_plus_list + test_labels_minus_list
#print(train_data)
print(train_labels)
# Out:
# ['+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '+', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']

# %%
plt.scatter(*zip(*plus_list),s=None,c=None,marker="+")
plt.scatter(*zip(*minus_list),s=None,c=None,marker="_")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import sklearn.linear_model as sk
clf = sk.Perceptron()
clf.fit(train_data,train_labels)

print('accuracy:', clf.score(train_data, train_labels))
print('accuracy:', clf.score(test_data, test_labels))
# Out:
# accuracy: 1.0
# accuracy: 0.9923954372623575
# D:\ProgramFiles\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
import numpy as np

colormap = np.array(['r', 'k'])
# Plot the original data
#plt.scatter(train_data, train_labels, c=colormap[train_labels], s=40)
#plt.scatter(*zip(*train_data),s=None,c=colormap[train_labels])
 
# Output the values
#print "Coefficient 0 " + str(clf.coef_[0,0])
#print "Coefficient 1 " + str(clf.coef_[0,1])
#print "Bias " + str(clf.intercept_)
plt.scatter(*zip(*plus_list),s=None,c=None,marker="+")
plt.scatter(*zip(*minus_list),s=None,c=None,marker="_")
plt.scatter(*zip(*test_plus_list),s=None,c=None,marker="*")
plt.scatter(*zip(*test_minus_list),s=None,c=None,marker="o")

# Calc the hyperplane (decision boundary)
ymin, ymax = plt.ylim()
w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(ymin, ymax)
yy = a * xx - (clf.intercept_[0]) / w[1]
 
# Plot the line
plt.plot(yy,xx, 'k-')
plt.show()

# %%
#for i in range(0, 20):
#    for j in range(0, 20):
#        plt.plot(x,y,Matrix[i][j],"ro")
#        print(Matrix[i][j])
#        if(j > i):
#            plt.plot([i], [j], marker="+", markersize=3, color="red")
#        if(j < i):
#            plt.plot([i], [j], marker="_", markersize=3, color="red")
#        if(j == i):
#            plt.plot([i], [j], marker='o', markersize=3, color="red")
#        
#plt.show()
