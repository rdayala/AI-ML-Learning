# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import random

# %%
plus_list = []
train_labels = []
minus_list = []
labels_plus_list = []
labels_minus_list = []
test_plus_list = []
test_labels_plus_list = []
test_minus_list = []
test_labels_minus_list = []

# %%
# generate data
for x in range(0, 20):
    for y in range(0, 20):
        if((y > x) and random.random() > 0.7):
            plus_list.append(tuple((x,y)))
            labels_plus_list.append('+')
        if((y < x) and random.random() > 0.7):
            minus_list.append(tuple((x,y)))
            labels_minus_list.append('-')
        if((y > x) and random.random() < 0.7):
            test_plus_list.append(tuple((x,y)))
            test_labels_plus_list.append('+')
        if((y < x) and random.random() < 0.7):
            test_minus_list.append(tuple((x,y)))
            test_labels_minus_list.append('-')
            
print(plus_list)
print("------------------------------------------------------------")
print(minus_list)
# Out:
# [(0, 2), (0, 3), (0, 5), (0, 6), (0, 7), (0, 8), (0, 12), (0, 19), (1, 4), (1, 5), (1, 10), (1, 14), (2, 4), (2, 7), (2, 9), (2, 18), (3, 4), (3, 9), (3, 18), (4, 5), (4, 8), (4, 13), (4, 17), (4, 19), (5, 8), (5, 9), (5, 12), (5, 15), (5, 16), (6, 8), (6, 10), (6, 11), (6, 12), (6, 19), (7, 12), (7, 14), (7, 16), (7, 18), (8, 13), (8, 16), (8, 17), (8, 19), (9, 15), (9, 17), (10, 14), (10, 15), (10, 19), (11, 14), (11, 16), (11, 18), (12, 17), (14, 15), (14, 16), (15, 17), (15, 19), (16, 18)]
# ------------------------------------------------------------
# ...

# %%
train_data = plus_list + minus_list
train_labels = labels_plus_list + labels_minus_list

test_data = test_plus_list + test_minus_list
test_labels = test_labels_plus_list + test_labels_minus_list

print(train_data)
print("------------------------------------------------------------")
print(train_labels)
# Out:
# [(0, 2), (0, 3), (0, 5), (0, 6), (0, 7), (0, 8), (0, 12), (0, 19), (1, 4), (1, 5), (1, 10), (1, 14), (2, 4), (2, 7), (2, 9), (2, 18), (3, 4), (3, 9), (3, 18), (4, 5), (4, 8), (4, 13), (4, 17), (4, 19), (5, 8), (5, 9), (5, 12), (5, 15), (5, 16), (6, 8), (6, 10), (6, 11), (6, 12), (6, 19), (7, 12), (7, 14), (7, 16), (7, 18), (8, 13), (8, 16), (8, 17), (8, 19), (9, 15), (9, 17), (10, 14), (10, 15), (10, 19), (11, 14), (11, 16), (11, 18), (12, 17), (14, 15), (14, 16), (15, 17), (15, 19), (16, 18), (2, 1), (3, 0), (4, 0), (4, 1), (5, 0), (5, 1), (5, 3), (6, 0), (6, 1), (7, 0), (7, 4), (7, 5), (9, 1), (9, 7), (10, 0), (10, 2), (10, 3), (10, 4), (10, 6), (10, 7), (11, 0), (11, 3), (11, 4), (12, 2), (12, 6), (12, 8), (12, 9), (13, 1), (13, 2), (13, 5), (13, 7), (13, 8), (13, 9), (13, 10), (13, 12), (14, 0), (14, 11), (14, 13), (15, 3), (15, 4), (15, 6), (15, 7), (15, 10), (16, 5), (16, 6), (16, 8), (16, 11), (16, 14), (17, 0), (17, 2), (17, 9), (17, 12), (17, 15), (17, 16), (18, 2), (18, 4),
# ...

# %%
plt.scatter(*zip(*plus_list),s=None,c=None,marker="+")
plt.scatter(*zip(*minus_list),s=None,c=None,marker="_")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Applying Perceptron algorithm to the data

# %%
import sklearn.linear_model as sk
clf = sk.Perceptron()
clf.fit(train_data,train_labels)

print('Training set Accuracy:', clf.score(train_data, train_labels))
print('Testing set Accuracy:', clf.score(test_data, test_labels))
# Out:
# Training set Accuracy: 1.0
# Testing set Accuracy: 1.0
# D:\ProgramFiles\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
# plotting Training Set
import numpy as np

#Plot the original data
plt.scatter(*zip(*plus_list),s=None,c='r',marker="+")
plt.scatter(*zip(*minus_list),s=None,c='k',marker="_")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Output the values
print("Coefficient 0 " + str(clf.coef_[0,0]))
print("Coefficient 1 " + str(clf.coef_[0,1]))
print("Bias " + str(clf.intercept_))
# Out:
# Coefficient 0 38.0
# Coefficient 1 -36.0
# Bias [-1.]

# %%
# plot training data
plt.scatter(*zip(*plus_list),s=None,c=None,marker="+")
plt.scatter(*zip(*minus_list),s=None,c=None,marker="_")

# plot testing data
plt.scatter(*zip(*test_plus_list),s=None,c=None,marker="*")
plt.scatter(*zip(*test_minus_list),s=None,c=None,marker="o")

# Calc the hyperplane (decision boundary)
ymin, ymax = plt.ylim()
w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(ymin, ymax)
yy = a * xx - (clf.intercept_[0]) / w[1]
 
# Plot the line
plt.plot(yy,xx, 'k-')
plt.show()
