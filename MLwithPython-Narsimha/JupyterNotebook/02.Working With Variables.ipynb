# %%
A = 10
B = 5

# %%
A
# Out:
# 10

# %%
B
# Out:
# 5

# %%
C = A+B

# %%
D = B/A

# %%
C
# Out:
# 15

# %%
D
# Out:
# 0.5

# %%
print(C)
# Out:
# 15

# %%
print(D)
# Out:
# 0.5

# %%
C
D
# Out:
# 0.5

# %%
print(C)
print(D)
# Out:
# 15
# 0.5

# %%
import math

# %%
math.sqrt(A)
# Out:
# 3.1622776601683795

# %%
round(math.sqrt(A))
# Out:
# 3

# %% [markdown]
# ---

# %%
greeting = "Hello"
name = "Alex"

# %%
message = greeting + " "+name

# %%
message
# Out:
# 'Hello Alex'
