# %%
import pandas as pd

# %%
# Method1 explicit path
statsDF = pd.read_csv("C:\\Users\\Bibhu\\Desktop\\Oracle_ML\\Assignment\\DemographicData.csv")

# %%
statsDF
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
# Method 2 : Change the working directory

import os

print(os.getcwd())
# Out:
# E:\Python_ML\Python_Demo_ML

# %%
os.chdir("C:\\Users\\Bibhu\\Desktop\\Oracle_ML\\Assignment")
print(os.getcwd())
# Out:
# C:\Users\Bibhu\Desktop\Oracle_ML\Assignment

# %%
statsDF2 = pd.read_csv("DemographicData.csv")

# %%
statsDF2
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
os.chdir("E:\\Python_ML\\Python_Demo_ML")
print(os.getcwd())
# Out:
# E:\Python_ML\Python_Demo_ML
