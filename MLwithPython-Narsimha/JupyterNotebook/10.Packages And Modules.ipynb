# %%
# matplotlib (package)
# pyplot (module)
import matplotlib.pyplot as plt

# %%
from matplotlib import pyplot as mplt2

# %%
import scrapy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-40a98f9a83be> in <module>()
# ----> 1 import scrapy
#
# ModuleNotFoundError: No module named 'scrapy'

# %%
import scrapy

# %%
scr
