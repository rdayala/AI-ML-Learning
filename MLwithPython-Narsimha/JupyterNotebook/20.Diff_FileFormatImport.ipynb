# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Import CSV File

# %%
csvDF = pd.read_csv("C://customer.csv",header=None,names=['custid','fname','lname','age','job'])

# %%
csvDF.head(10)
csvDF.tail()
csvDF.tail(10)
# Out:
#     custid     fname    lname  age                         job
# 0  4000001  Kristina    Chung   55                       Pilot
# 1  4000002     Paige     Chen   74                     Teacher
# 2  4000003    Sherri   Melton   34                 Firefighter
# 3  4000004  Gretchen     Hill   66  Computer hardware engineer
# 4  4000005     Karen  Puckett   74                      Lawyer

# %%
# Change the column names
csvDF.columns=['CustID','Fname','Lname','Age','Job']

# %%
csvDF.head()
# Out:
#     CustID     Fname    Lname  Age                         Job
# 0  4000001  Kristina    Chung   55                       Pilot
# 1  4000002     Paige     Chen   74                     Teacher
# 2  4000003    Sherri   Melton   34                 Firefighter
# 3  4000004  Gretchen     Hill   66  Computer hardware engineer
# 4  4000005     Karen  Puckett   74                      Lawyer

# %%
# Rename a single column
csvDF=csvDF.rename(columns = {'CustID':'CustId'})

# %%
csvDF.head()
# Out:
#     CustId     Fname    Lname  Age                         Job
# 0  4000001  Kristina    Chung   55                       Pilot
# 1  4000002     Paige     Chen   74                     Teacher
# 2  4000003    Sherri   Melton   34                 Firefighter
# 3  4000004  Gretchen     Hill   66  Computer hardware engineer
# 4  4000005     Karen  Puckett   74                      Lawyer

# %% [markdown]
# # Import From Microsoft Excel files

# %%
excelDF = pd.read_excel("C://SuperStore.xls", sheet_name = "Orders")

# %%
excelDF.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# # Import Data From Json File

# %%
df = pd.read_json("C://employee.json")

# %%
df.head()
# Out:
#    assignee assignees author_association  \
# 0       NaN        []        CONTRIBUTOR
# 1       NaN        []               NONE
# 2       NaN        []               NONE
# 3       NaN        []               NONE
# 4       NaN        []        CONTRIBUTOR
#
#                                                 body closed_at  comments  \
# 0                                                          NaT         2
# 1  #### Problem description\r\n\r\nWhen using Pan...       NaT         0
# 2  Fixes bug GH19497 - previously, renaming an in...       NaT         1
# 3  #### Code Sample\r\n\r\n```python\r\ndf.to_csv...       NaT         1
# 4  - [x] closes #21012\r\n- [x] tests added / pas...       NaT         2
#
#                                         comments_url          created_at  \
# 0  https://api.github.com/repos/pandas-dev/pandas... 2018-05-14 12:21:28
# 1  https://api.github.com/repos/pandas-dev/pandas... 2018-05-14 10:33:43
# 2  https://api.github.com/repos/pandas-dev/pandas... 2018-05-14 06:57:19
# 3  https://api.github.com/repos/pandas-dev/pandas... 2018-05-14 06:33:49
# 4  https://api.github.com/repos/pandas-dev/pandas... 2018-05-14 01:02:31
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url  \
# 0    https://github.com/pandas-dev/pandas/pull/21033
# 1  https://github.com/pandas-dev/pandas/issues/21032
# 2    https://github.com/pandas-dev/pandas/pull/21029
# 3  https://github.com/pandas-dev/pandas/issues/21028
# 4    https://github.com/pandas-dev/pandas/pull/21027
#
#                          ...                          locked  \
# 0                        ...                           False
# 1                        ...                           False
# 2                        ...                           False
# 3                        ...                           False
# 4                        ...                           False
#
#                                            milestone number  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...  21033
# 1                                               None  21032
# 2  {'url': 'https://api.github.com/repos/pandas-d...  21029
# 3                                               None  21028
# 4  {'url': 'https://api.github.com/repos/pandas-d...  21027
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                NaN
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                    repository_url  state  \
# 0  https://api.github.com/repos/pandas-dev/pandas   open
# 1  https://api.github.com/repos/pandas-dev/pandas   open
# 2  https://api.github.com/repos/pandas-dev/pandas   open
# 3  https://api.github.com/repos/pandas-dev/pandas   open
# 4  https://api.github.com/repos/pandas-dev/pandas   open
#
#                                                title          updated_at  \
# 0              TST: add arithmetic operators fixture 2018-05-14 13:14:51
# 1  Pandas read_excel uses blank column heading as... 2018-05-14 10:33:56
# 2  BUG: Fixed 19497 - previously, renaming an ind... 2018-05-14 12:35:46
# 3                   to_csv fails with long file path 2018-05-14 13:36:18
# 4  BUG: Iteration over DatetimeIndex stops at chu... 2018-05-14 13:34:13
#
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 user
# 0  {'login': 'jreback', 'id': 953992, 'avatar_url...
# 1  {'login': 'kentmaxwell', 'id': 5932455, 'avata...
# 2  {'login': 'charlie0389', 'id': 3690467, 'avata...
# 3  {'login': 'Damdinov', 'id': 6833176, 'avatar_u...
# 4  {'login': 'kittoku', 'id': 38392245, 'avatar_u...
#
# [5 rows x 23 columns]

# %% [markdown]
# # import images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('C://Files//man.png')
plt.axis("off")
imgplot = plt.imshow(img)

# df = pd.read_json("C://employee.json")

# %% [markdown]
# # Operation on DataFrame

# %%
excelDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 21 columns):
# Row ID           599 non-null int64
# Order ID         599 non-null object
# Order Date       599 non-null datetime64[ns]
# Ship Date        599 non-null datetime64[ns]
# Ship Mode        599 non-null object
# Customer ID      599 non-null object
# Customer Name    599 non-null object
# Segment          599 non-null object
# Country          599 non-null object
# City             599 non-null object
# State            599 non-null object
# Postal Code      599 non-null int64
# Region           599 non-null object
# Product ID       599 non-null object
# Category         599 non-null object
# Sub-Category     599 non-null object
# Product Name     599 non-null object
# Sales            599 non-null float64
# Quantity         599 non-null int64
# Discount         599 non-null float64
# Profit           599 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 98.4+ KB

# %%
excelDF.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
excelDF['Order Date'] = excelDF['Order Date'].apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
excelDF['Ship Date'] = excelDF['Ship Date'].apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
excelDF.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
excelDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 21 columns):
# Row ID           599 non-null int64
# Order ID         599 non-null object
# Order Date       599 non-null object
# Ship Date        599 non-null object
# Ship Mode        599 non-null object
# Customer ID      599 non-null object
# Customer Name    599 non-null object
# Segment          599 non-null object
# Country          599 non-null object
# City             599 non-null object
# State            599 non-null object
# Postal Code      599 non-null int64
# Region           599 non-null object
# Product ID       599 non-null object
# Category         599 non-null object
# Sub-Category     599 non-null object
# Product Name     599 non-null object
# Sales            599 non-null float64
# Quantity         599 non-null int64
# Discount         599 non-null float64
# Profit           599 non-null float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 98.4+ KB

# %%
# slice the DataFrame 
excelDF[10:15]
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 10      11  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 11      12  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 12      13  CA-2017-114412  2017-04-15  2017-04-20  Standard Class
# 13      14  CA-2016-161389  2016-12-05  2016-12-10  Standard Class
# 14      15  US-2015-118983  2015-11-22  2015-11-26  Standard Class
#
#    Customer ID    Customer Name      Segment        Country         City  \
# 10    BH-11710  Brosina Hoffman     Consumer  United States  Los Angeles
# 11    BH-11710  Brosina Hoffman     Consumer  United States  Los Angeles
# 12    AA-10480     Andrew Allen     Consumer  United States      Concord
# 13    IM-15070     Irene Maddox     Consumer  United States      Seattle
# 14    HP-14815    Harold Pawlan  Home Office  United States   Fort Worth
#
#       ...    Postal Code   Region       Product ID         Category  \
# 10    ...          90032     West  FUR-TA-10001539        Furniture
# 11    ...          90032     West  TEC-PH-10002033       Technology
# 12    ...          28027    South  OFF-PA-10002365  Office Supplies
# 13    ...          98103     West  OFF-BI-10003656  Office Supplies
# 14    ...          76106  Central  OFF-AP-10002311  Office Supplies
#
#    Sub-Category                                       Product Name     Sales  \
# 10       Tables           Chromcraft Rectangular Conference Tables  1706.184
# 11       Phones      Konftel 250 Conference phone - Charcoal black   911.424
# 12        Paper                                         Xerox 1967    15.552
# 13      Binders        Fellowes PB200 Plastic Comb Binding Machine   407.976
# 14   Appliances  Holmes Replacement Filter for HEPA Air Cleaner...    68.810
#
#     Quantity  Discount    Profit
# 10         9       0.2   85.3092
# 11         4       0.2   68.3568
# 12         3       0.2    5.4432
# 13         3       0.2  132.5922
# 14         5       0.8 -123.8580
#
# [5 rows x 21 columns]

# %%
# display every 100th row
excelDF[::100]
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 100     101  CA-2016-158568  2016-08-29  2016-09-02  Standard Class
# 200     201  CA-2017-105074  2017-06-24  2017-06-29  Standard Class
# 300     301  CA-2016-142545  2016-10-28  2016-11-03  Standard Class
# 400     401  CA-2016-108987  2016-09-08  2016-09-10    Second Class
# 500     501  US-2016-105578  2016-05-30  2016-06-04  Standard Class
#
#     Customer ID     Customer Name      Segment        Country        City  \
# 0      CG-12520       Claire Gute     Consumer  United States   Henderson
# 100    RB-19465      Rick Bensley  Home Office  United States     Chicago
# 200    MB-17305   Maria Bertelson     Consumer  United States       Akron
# 300    JD-15895  Jonathan Doherty    Corporate  United States  Belleville
# 400    AG-10675       Anna Gayman     Consumer  United States     Houston
# 500    MY-17380   Maribeth Yedwab    Corporate  United States      Parker
#
#       ...    Postal Code   Region       Product ID         Category  \
# 0     ...          42420    South  FUR-BO-10001798        Furniture
# 100   ...          60610  Central  TEC-AC-10001767       Technology
# 200   ...          44312     East  OFF-PA-10002666  Office Supplies
# 300   ...           7109     East  OFF-PA-10004243  Office Supplies
# 400   ...          77036  Central  OFF-ST-10000934  Office Supplies
# 500   ...          80134     West  OFF-BI-10001670  Office Supplies
#
#     Sub-Category                                       Product Name    Sales  \
# 0      Bookcases                  Bush Somerset Collection Bookcase  261.960
# 100  Accessories  SanDisk Ultra 64 GB MicroSDHC Class 10 Memory ...   95.976
# 200        Paper  Southworth 25% Cotton Linen-Finish Paper & Env...   21.744
# 300        Paper                                         Xerox 1939   56.910
# 400      Storage             Contico 72"H Heavy-Duty Storage System  131.136
# 500      Binders                       Vinyl Sectional Post Binders   22.620
#
#      Quantity  Discount   Profit
# 0           2       0.0  41.9136
# 100         3       0.2 -10.7973
# 200         3       0.2   6.7950
# 300         3       0.0  27.3168
# 400         4       0.2 -32.7840
# 500         2       0.7 -15.0800
#
# [6 rows x 21 columns]

# %%
excelDF.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
excelDF['Ship Mode']
# Out:
# 0        Second Class
# 1        Second Class
# 2        Second Class
# 3      Standard Class
# 4      Standard Class
# 5      Standard Class
# 6      Standard Class
# 7      Standard Class
# 8      Standard Class
# 9      Standard Class
# 10     Standard Class
# 11     Standard Class
# 12     Standard Class
# 13     Standard Class
# 14     Standard Class
# 15     Standard Class
# 16     Standard Class
# 17       Second Class
# 18       Second Class
# 19       Second Class
# 20       Second Class
# 21     Standard Class
# 22     Standard Class
# 23       Second Class
# 24     Standard Class
# 25       Second Class
# 26       Second Class
# 27     Standard Class
# 28     Standard Class
# 29     Standard Class
#             ...
# 569    Standard Class
# 570    Standard Class
# 571    Standard Class
# 572    Standard Class
# 573    Standard Class
# 574    Standard Class
# 575      Second Class
# 576      Second Class
# 577      Second Class
# 578    Standard Class
# 579    Standard Class
# 580    Standard Class
# 581    Standard Class
# 582    Standard Class
# 583    Standard Class
# 584    Standard Class
# 585    Standard Class
# 586    Standard Class
# 587    Standard Class
# 588    Standard Class
# 589    Standard Class
# 590    Standard Class
# 591    Standard Class
# 592    Standard Class
# 593    Standard Class
# 594    Standard Class
# 595    Standard Class
# 596    Standard Class
# 597    Standard Class
# 598       First Class
# Name: Ship Mode, Length: 599, dtype: object

# %%
excelDF['Ship Mode'].count()
# Out:
# 599

# %%
excelDF.Quantity.max()
# Out:
# 14

# %%
excelDF.groupby('Ship Mode').Quantity.max()
# Out:
# Ship Mode
# First Class       10
# Same Day           7
# Second Class      14
# Standard Class    14
# Name: Quantity, dtype: int64

# %%
excelDF.groupby(['Ship Mode','Region']).Sales.mean()
# Out:
# Ship Mode
# First Class       212.250253
# Same Day          294.817500
# Second Class      258.377122
# Standard Class    274.519970
# Name: Sales, dtype: float64

# %%
excelDF.Region.unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
excelDF[["Sales","Region"]]
# Out:
#          Sales   Region
# 0     261.9600    South
# 1     731.9400    South
# 2      14.6200     West
# 3     957.5775    South
# 4      22.3680    South
# 5      48.8600     West
# 6       7.2800     West
# 7     907.1520     West
# 8      18.5040     West
# 9     114.9000     West
# 10   1706.1840     West
# 11    911.4240     West
# 12     15.5520    South
# 13    407.9760     West
# 14     68.8100  Central
# 15      2.5440  Central
# 16    665.8800  Central
# 17     55.5000     West
# 18      8.5600     West
# 19    213.4800     West
# 20     22.7200     West
# 21     19.4600  Central
# 22     60.3400  Central
# 23     71.3720     East
# 24   1044.6300     West
# 25     11.6480     West
# 26     90.5700     West
# 27   3083.4300     East
# 28      9.6180     East
# 29    124.2000     East
# ..         ...      ...
# 569   451.1520     West
# 570    72.4500     East
# 571    13.9600     East
# 572    33.2640     East
# 573    14.8500     East
# 574     8.8200     West
# 575   160.7200     West
# 576    19.9200     West
# 577     7.3000     West
# 578    69.7120  Central
# 579     8.7920  Central
# 580    51.5200     West
# 581   470.3760     West
# 582   105.5840     West
# 583    31.1520     West
# 584     6.7830     West
# 585   406.3680     West
# 586    70.9800    South
# 587   294.9300    South
# 588    84.7840     West
# 589    20.7360     West
# 590    16.8210     West
# 591    10.3680     West
# 592     9.3440  Central
# 593    31.2000  Central
# 594    76.1200     West
# 595  1199.9760     West
# 596   445.9600     West
# 597   327.7600     West
# 598    11.6320     East
#
# [599 rows x 2 columns]

# %%
excelDF[["Sales","Region"]].head()

# excelDF.Region.unique()
# Out:
#       Sales Region
# 0  261.9600  South
# 1  731.9400  South
# 2   14.6200   West
# 3  957.5775  South
# 4   22.3680  South

# %%
excelDF[100:105]['Region']
# Out:
# 100    Central
# 101    Central
# 102    Central
# 103       West
# 104       West
# Name: Region, dtype: object

# %%
excelDF.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
excelDF["Calc"]=excelDF.Sales * excelDF.Profit

# %%
excelDF.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City      ...        \
# 0      Claire Gute   Consumer  United States        Henderson      ...
# 1      Claire Gute   Consumer  United States        Henderson      ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles      ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale      ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale      ...
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# 1  South  FUR-CH-10000454        Furniture       Chairs
# 2   West  OFF-LA-10000240  Office Supplies       Labels
# 3  South  FUR-TA-10000577        Furniture       Tables
# 4  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#    Discount    Profit           Calc
# 0      0.00   41.9136   10979.686656
# 1      0.00  219.5820  160720.849080
# 2      0.00    6.8714     100.459868
# 3      0.45 -383.0310 -366781.867403
# 4      0.20    2.5164      56.286835
#
# [5 rows x 22 columns]

# %%
excelDF.drop("Calc",axis=1,inplace=True)

# excelDF =excelDF.drop("Calc",axis=1)

# %%
excelDF.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
excelDF.iat[1,0]
# Out:
# 2

# %%
excelDF.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]
