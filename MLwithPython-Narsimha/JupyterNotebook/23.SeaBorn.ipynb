# %%
import pandas as pd
DF = pd.read_csv("C:\\Users\\Bibhu\\Desktop\\Oracle_ML\\Assignment\\DemographicData.csv")

DF.columns=['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
DF
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %% [markdown]
# # Creating a univariate distribution in seaborn with distplot()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize']=9,5
plt.rcParams["patch.force_edgecolor"] = True

# %%
DF.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
DF.columns=['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
"""
seaborn.distplot()
A quick look at a univariate distribution in seaborn is the distplot(),
this will draw a histogram and fit a kernel density estimate (KDE).

A univariate distribution refers to the distribution of a single random variable


A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.

density estimation is the construction of an estimate, based on observed data

The kernel density estimate is a useful tool for plotting the shape of a distribution. Like the histogram, the KDE plots encodes the density of observations on one axis with height along the other axis
"""

# %%
# Tells how many countries have internet users , like 20-30% internet countries count more, 100% internet access countries count is less
# plt.rcParams["patch.force_edgecolor"] = True
plt.ticklabel_format(style="sci")
plt.yticks()
#plt.ylim(0,10)
s= sns.distplot(DF.InternetUsers,bins=30,kde_kws = {'linewidth': 3})
#p=plt.hist(DF.InternetUsers,bins=30)
plt.show()

# %%
    sns.distplot(DF["InternetUsers"],hist=False,kde=True,kde_kws = {'linewidth': 3})
    plt.ylabel('Density')
# Out:
# Text(0,0.5,'Density')

# %%
# boxplot(), shows the distribution of quantitative data in a way that facilitates comparisons between variables 
#  the extra pointers ploted indicate outliners (e.g. few high income rate class having high birthrate)
vis2 = sns.boxplot(data=DF,x="IncomeGroup",y="BirthRate")

# %%
# stats to verify outliners of box plotting
print(DF[DF.IncomeGroup == "High income"]['BirthRate'].max())
print(DF[DF.IncomeGroup == "High income"]['BirthRate'].median())
print(DF[DF.IncomeGroup == "High income"]['BirthRate'].min())
# print(DF[(DF.IncomeGroup == "High income") & (DF.BirthRate.between(7.9,11.3))].count())
# print(DF[(DF.IncomeGroup == "High income") & (DF.BirthRate.between(11.3,35.36))].count())
# print(DF[(DF.IncomeGroup == "High income") & (DF.BirthRate.between(7.9,11.3))].sort_values('BirthRate'))
# print(DF[(DF.IncomeGroup == "High income") & ((DF.BirthRate>=11.3) & (DF.BirthRate<=36))].sort_values('BirthRate'))

DF[DF.IncomeGroup == "High income"]['BirthRate'].describe()
# Out:
# 35.361999999999995
# 11.3
# 7.9
# count    67.000000
# mean     12.753433
# std       4.467886
# min       7.900000
# 25%      10.100000
# 50%      11.300000
# 75%      14.545000
# max      35.362000
# Name: BirthRate, dtype: float64

# %%
# BirthRate Vs Internet Users 
#scatter_kws is a wrapper for plt.scatter (matplotlib.pyplot.scatter), so to size the markers we need to pass value to the scatter_kws as a dictionary(key:value) , where s is the size of the marker

vis3 = sns.lmplot(data = DF, x="InternetUsers",y="BirthRate",fit_reg=False,hue="IncomeGroup",size=5, scatter_kws={"s":50})
#DF.head()
